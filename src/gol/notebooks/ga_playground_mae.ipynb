# %%
from gol.patterns import get_and_save_pattern_1, get_and_save_pattern_2

patterns = [
    get_and_save_pattern_1(20, 20, 5),
    get_and_save_pattern_2(20, 20, 5)
]

# %%
from visualize import visualize_current_state

for ca in patterns:
    visualize_current_state(ca)

# %%
raw_export_dir = "../../../data/gol-ga/evolution/mae/pattern_{pattern_idx}_best_fit_{best_fit_idx}_initial_states.png"
evolved_export_dir = "../../../data/gol-ga/evolution/mae/pattern_{pattern_idx}_best_fit_{best_fit_idx}_after_steps_{ca_steps}.png"
raw_plot_title = "Pattern {pattern_idx}, Best Fit {best_fit_idx}, Initial States"
evolved_plot_title = "Pattern {pattern_idx}, Best Fit {best_fit_idx}, After {ca_steps} Steps Fitness: {fitness}"

# %%
best_checkpoint_dir_before = "../../../data/reports/gol-ga/states_over_time/mae/pattern_{pattern_idx}_generation_{generation}_before.png"
best_checkpoint_title_before = "Pattern {pattern_idx}, Generation {generation}, Fitness: {fitness}, Initial States"

best_checkpoint_dir_after = "../../../data/reports/gol-ga/states_over_time/mae/pattern_{pattern_idx}_generation_{generation}_after.png"
best_checkpoint_title_after = "Pattern {pattern_idx}, Generation {generation}, Fitness: {fitness}, After {ca_steps} Steps"

# %%
from core.evolution import evolve_and_visualize_patterns, checkpoint_save_function
import config

evolve_and_visualize_patterns(ca_name=config.CA_NAME_GAME_OF_LIFE,
                              patterns=patterns,
                              population_size=config.DEFAULT_POPULATION_SIZE,
                              n_generations=config.DEFAULT_N_GENERATIONS,
                              crossover_rate=config.DEFAULT_CROSSOVER_RATE,
                              mutation_rate=config.DEFAULT_MUTATION_RATE,
                              retention_rate=config.DEFAULT_RETENTION_RATE,
                              random_selection_rate=config.DEFAULT_RANDOM_SELECTION_RATE,
                              steps=config.DEFAULT_GOL_NUM_STEPS,
                              fitness_function_name=config.FITNESS_FUNCTION_MAE,
                              raw_export_directory=raw_export_dir,
                              raw_plot_title=raw_plot_title,
                              evolved_export_directory=evolved_export_dir,
                              evolved_plot_title=evolved_plot_title,
                              callback_function=checkpoint_save_function(
                                  best_checkpoint_dir_before,
                                  best_checkpoint_title_before,
                                  best_checkpoint_dir_after,
                                  best_checkpoint_title_after
                              ),
                              callback_interval=config.DEFAULT_CALLBACK_INTERVAL)
# Out:
# #### Evolving Pattern 1 ####
#
# Generation 0: Best fitness 0.85
# Saving checkpoint for Pattern#1 in 0
# Generation 1: Best fitness 0.895
# Generation 2: Best fitness 0.895
# Generation 3: Best fitness 0.895
# Generation 4: Best fitness 0.895
# Generation 5: Best fitness 0.895
# Generation 6: Best fitness 0.895
# Generation 7: Best fitness 0.895
# Generation 8: Best fitness 0.895
# Generation 9: Best fitness 0.895
# Generation 10: Best fitness 0.895
# Generation 11: Best fitness 0.895
# Generation 12: Best fitness 0.895
# Generation 13: Best fitness 0.895
# Generation 14: Best fitness 0.895
# Generation 15: Best fitness 0.895
# Generation 16: Best fitness 0.895
# Generation 17: Best fitness 0.895
# Generation 18: Best fitness 0.895
# Generation 19: Best fitness 0.895
# Generation 20: Best fitness 0.895
# Generation 21: Best fitness 0.895
# Generation 22: Best fitness 0.895
# Generation 23: Best fitness 0.895
# Generation 24: Best fitness 0.895
# Generation 25: Best fitness 0.895
# ...
