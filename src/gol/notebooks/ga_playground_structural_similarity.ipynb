# %%
from gol.patterns import get_and_save_pattern_1, get_and_save_pattern_2

patterns = [
    get_and_save_pattern_1(20, 20, 5),
    get_and_save_pattern_2(20, 20, 5)
]

# %%
from visualize import visualize_current_state

for ca in patterns:
    visualize_current_state(ca)

# %%
from core.evolution import evolve_and_visualize_patterns

evolve_and_visualize_patterns(ca_name="game_of_life",
                              patterns=patterns,
                              population_size=1000,
                              n_generations=500,
                              crossover_rate=0.5,
                              mutation_rate=0.1,
                              retention_rate=0.6,
                              random_selection_rate=0.05,
                              steps=5,
                              fitness_function_name="structural_similarity")
# Out:
# #### Evolving Pattern 1 ####
#
# Generation 0: Best fitness 0.18468991067096377
# Generation 1: Best fitness 0.18468991067096377
# Generation 2: Best fitness 0.18468991067096377
# Generation 3: Best fitness 0.18468991067096377
# Generation 4: Best fitness 0.2509066105010796
# Generation 5: Best fitness 0.2509066105010796
# Generation 6: Best fitness 0.2509066105010796
# Generation 7: Best fitness 0.2509066105010796
# Generation 8: Best fitness 0.2509066105010796
# Generation 9: Best fitness 0.2509066105010796
# Generation 10: Best fitness 0.2509066105010796
# Generation 11: Best fitness 0.2509066105010796
# Generation 12: Best fitness 0.2509066105010796
# Generation 13: Best fitness 0.2509066105010796
# Generation 14: Best fitness 0.2509066105010796
# Generation 15: Best fitness 0.2509066105010796
# Generation 16: Best fitness 0.2509066105010796
# Generation 17: Best fitness 0.2509066105010796
# Generation 18: Best fitness 0.2509066105010796
# ...
