# %%
from wolfram.patterns import get_and_save_pattern_1, get_and_save_pattern_2

patterns = [
    get_and_save_pattern_1(20, 19),
    get_and_save_pattern_2(20, 19)
]

# %%
from visualize import visualize_current_state

for ca in patterns:
    visualize_current_state(ca)

# %%
raw_export_dir = "../../../data/wolfram-ga/evolution/structural_similarity/pattern_{pattern_idx}_best_fit_{best_fit_idx}_initial_states.png"
evolved_export_dir = "../../../data/wolfram-ga/evolution/structural_similarity/pattern_{pattern_idx}_best_fit_{best_fit_idx}_after_steps_{ca_steps}.png"
raw_plot_title = "Pattern {pattern_idx}, Best Fit {best_fit_idx}, Initial States"
evolved_plot_title = "Pattern {pattern_idx}, Best Fit {best_fit_idx}, After {ca_steps} Steps Fitness: {fitness}"

# %%
from core.evolution import evolve_and_visualize_patterns
import config

evolve_and_visualize_patterns(ca_name="wolfram_ca",
                              patterns=patterns,
                              population_size=config.DEFAULT_POPULATION_SIZE,
                              n_generations=config.DEFAULT_N_GENERATIONS,
                              crossover_rate=config.DEFAULT_CROSSOVER_RATE,
                              mutation_rate=config.DEFAULT_MUTATION_RATE,
                              retention_rate=config.DEFAULT_RETENTION_RATE,
                              random_selection_rate=config.DEFAULT_RANDOM_SELECTION_RATE,
                              steps=config.DEFAULT_WOLFRAM_NUM_STEPS,
                              fitness_function_name="structural_similarity",
                              raw_export_directory=raw_export_dir,
                              raw_plot_title=raw_plot_title,
                              evolved_export_directory=evolved_export_dir,
                              evolved_plot_title=evolved_plot_title)
# Out:
# #### Evolving Pattern 1 ####
#
# Generation 0: Best fitness 0.30518899936472554
# Generation 1: Best fitness 0.30518899936472554
# Generation 2: Best fitness 0.3197900545271211
# Generation 3: Best fitness 0.32222036764533174
# Generation 4: Best fitness 0.32222036764533174
# Generation 5: Best fitness 0.32222036764533174
# Generation 6: Best fitness 0.32222036764533174
# Generation 7: Best fitness 0.32222036764533174
# Generation 8: Best fitness 0.32317956175841805
# Generation 9: Best fitness 0.32317956175841805
# Generation 10: Best fitness 0.32317956175841805
# Generation 11: Best fitness 0.32317956175841805
# Generation 12: Best fitness 0.32317956175841805
# Generation 13: Best fitness 0.32317956175841805
# Generation 14: Best fitness 0.32317956175841805
# Generation 15: Best fitness 0.32317956175841805
# Generation 16: Best fitness 0.32317956175841805
# Generation 17: Best fitness 0.3414955976041485
# Generation 18: Best fitness 0.3491773636954998
# ...
